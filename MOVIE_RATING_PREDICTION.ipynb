# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/IMDb Movies India.csv', encoding='latin-1')

# %% [markdown]
# Display the top 10 rows of the dataset

# %%
data.head(10)
# Out:
#                                  Name    Year Duration  \
# 0                                         NaN      NaN
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 2                         #Homecoming  (2021)   90 min
# 3                             #Yaaram  (2019)  110 min
# 4                   ...And Once Again  (2010)  105 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 7                      .in for Motion  (2008)   59 min
# 8                  ?: A Question Mark  (2012)   82 min
# 9                            @Andheri  (2014)  116 min
#
#                        Genre  Rating  Votes            Director  \
# 0                      Drama     NaN    NaN       J.S. Randhawa
# 1                      Drama     7.0      8       Gaurav Bakshi
# 2             Drama, Musical     NaN    NaN  Soumyajit Majumdar
# 3            Comedy, Romance     4.4     35          Ovais Khan
# ...

# %%
#Display the last 10 rows of the dataset
data.tail(10)
# Out:
#                       Name    Year Duration                 Genre  Rating  \
# 15499        Zulm Ka Jawab  (1995)      NaN                Action     NaN
# 15500      Zulm Ka Muqabla  (1993)      NaN                Action     NaN
# 15501      Zulm Ki Hukumat  (1992)      NaN  Action, Crime, Drama     5.3
# 15502        Zulm Ki Pukar  (1979)      NaN                Action     NaN
# 15503      Zulm Ki Zanjeer  (1989)  125 min  Action, Crime, Drama     5.8
# 15504  Zulm Ko Jala Doonga  (1988)      NaN                Action     4.6
# 15505                Zulmi  (1999)  129 min         Action, Drama     4.5
# 15506            Zulmi Raj  (2005)      NaN                Action     NaN
# 15507        Zulmi Shikari  (1988)      NaN                Action     NaN
# 15508         Zulm-O-Sitam  (1998)  130 min         Action, Drama     6.2
#
#       Votes           Director                Actor 1              Actor 2  \
# 15499   NaN    Surinder Kapoor            Goga Kapoor        Shakti Kapoor
# ...

# %%
#Find the Shape of data set
data.shape
# Out:
# (15509, 10)

# %%
print('Number of rows:', data.shape[0])
print('Number of columns:', data.shape[1])
# Out:
# Number of rows: 15509
# Number of columns: 10

# %%
#Getting information about dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
# Missing value in the dataset
print("Any missing value",data.isnull().values.any())
# Out:
# Any missing value True

# %%
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
per_missing=(data.isnull().sum()*100/len(data))
per_missing
# Out:
# Name         0.000000
# Year         3.404475
# Duration    53.317429
# Genre       12.102650
# Rating      48.939326
# Votes       48.932878
# Director     3.385131
# Actor 1     10.426204
# Actor 2     15.371720
# Actor 3     20.272100
# dtype: float64

# %%
#Drop all the missing values
data.dropna(axis=0,)
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
#Check for duplicate values
dup_data =data.duplicated().any()

# %%
print(dup_data)
# Out:
# True

# %%
data = data.drop_duplicates()
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
#get overall statical about the dataframe
data.describe(include='all')
# Out:
#           Name    Year Duration  Genre       Rating Votes      Director  \
# count    15503   14976     7239  13627  7919.000000  7920         14979
# unique   13838     102      182    485          NaN  2034          5938
# top     Anjaam  (2019)  120 min  Drama          NaN     8  Jayant Desai
# freq         7     408      240   2779          NaN   227            58
# mean       NaN     NaN      NaN    NaN     5.841621   NaN           NaN
# std        NaN     NaN      NaN    NaN     1.381777   NaN           NaN
# min        NaN     NaN      NaN    NaN     1.100000   NaN           NaN
# 25%        NaN     NaN      NaN    NaN     4.900000   NaN           NaN
# 50%        NaN     NaN      NaN    NaN     6.000000   NaN           NaN
# 75%        NaN     NaN      NaN    NaN     6.800000   NaN           NaN
# max        NaN     NaN      NaN    NaN    10.000000   NaN           NaN
#
#             Actor 1 Actor 2 Actor 3
# count         13888   13122   12363
# ...

# %%
#Display the movies columns
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
# Convert 'Votes' column to numeric, handling non-numeric values
data['Votes'] = pd.to_numeric(data['Votes'], errors='coerce')

# Calculate mean votes by year
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# (2013)    213.975806
# (2008)    203.924731
# (2003)    198.535714
# (2010)    197.388350
# (2006)    193.934066
#              ...
# (1924)           NaN
# (1926)           NaN
# (1928)           NaN
# (1930)           NaN
# (2022)           NaN
# Name: Votes, Length: 102, dtype: float64

# %%
data.groupby('Year')['Votes'].mean().sort_values(ascending=False)
# Out:
# Year
# (2013)    213.975806
# (2008)    203.924731
# (2003)    198.535714
# (2010)    197.388350
# (2006)    193.934066
#              ...
# (1924)           NaN
# (1926)           NaN
# (1928)           NaN
# (1930)           NaN
# (2022)           NaN
# Name: Votes, Length: 102, dtype: float64

# %%
data = data.sort_values(by='Year')
sns.set(rc={'figure.figsize':(80,30)})
sns.barplot(x='Year',y='Votes',data=data)
plt.title('Votes by Year')
plt.xlabel('Year')
plt.ylabel('Votes')
plt.locator_params(axis='x', nbins=10)
plt.show()
# Out:
# <ipython-input-52-d1d0f30d8e71>:7: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.category.StrCategoryLocator'>
#   plt.locator_params(axis='x', nbins=10)

# %%
#Highest average rating for each director
data.columns
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='object')

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Saif Ali Sayeed    10.0
# Sriram Raja         9.7
# Bobby Kumar         9.6
# Arvind Pratap       9.4
# Ashish Dubey        9.4
#                    ...
# Zia Khan Lodhi      NaN
# Zia-ur-Rasheed      NaN
# Zohra               NaN
# Zubeida             NaN
# Zul Vellani         NaN
# Name: Rating, Length: 5938, dtype: float64

# %% [markdown]
# #Top 10 highest Rated movies

# %%
top_10len=data.nlargest(10,'Rating')[['Name','Rating','Director']]\
.set_index('Name')

# %%
top_10len
# Out:
#                                   Rating             Director
# Name
# Love Qubool Hai                     10.0      Saif Ali Sayeed
# Half Songs                           9.7          Sriram Raja
# Breed                                9.6          Bobby Kumar
# Ram-Path                             9.4         Ashish Dubey
# Gho Gho Rani                         9.4         Munni Pankaj
# The Reluctant Crime                  9.4        Arvind Pratap
# June                                 9.4       Suhrud Godbole
# Ashok Vatika                         9.3        Rahul Mallick
# Mahakaleshwar - Legends of Shiva     9.3  Avinash Kumar Singh
# God of gods                          9.3         Venkatesh Bk
